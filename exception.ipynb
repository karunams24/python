# %%
#exception handling
try:
    value=int(input("enter a number:"))
    ans=5/value
except ZeroDivisionError:
    print("error!,division by zero is not allowed")
else:
    print("result is:",ans)
finally:
    print("execution finished")
# Out:
# enter a number: 2
# result is: 2.5
# execution finished

# %%
#multiple exception
try:
    num1=int(input("enter first num:"))
    num2=int(input("enter second num:"))
    ans=num1/num2
except ZeroDivisionError:
    print("error:division with zero is not executable")
except ValueError:
    print("Invalid input!enter valid data")
else:
    print("result is:",ans)
finally:
    print("execution completed")
# Out:
# enter first num: 4
# enter second num: 0
# error:division with zero is not executable
# execution completed
